# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#data for Corporate Bonds
df=pd.read_excel (r'C:\Users\user\Desktop\Yield curves.xlsx', sheet_name='Sheet1') 

#print(df)

df2= df.apply(pd.to_numeric, errors='çoerce')
df2.dtypes
df3=df2.dropna(subset = ['Time to Maturity (1st July)','Yield to Maturity (1st July)'])

df4=df3.drop([74])
print(df4)

'''plt.figure(figsize=(16,5))

sns.regplot(x="Time to Maturity (2nd July)",y="Yield to Maturity (2nd July)",data=df,order=4)
sns.regplot('Time to Maturity (1st July)', 'Yield to Maturity (1st July)', df,order=4)
plt.xlabel("Time to Maturity",fontsize=16)
plt.ylabel("")
plt.title("1st July vs 2nd July")'''

#Plot of 1st July vs 2nd July
'''plt.figure(figsize=(18,8))
data=df[['Time to Maturity (2nd July)','Yield to Maturity (2nd July)']]
x=data['Time to Maturity (2nd July)']
y=data['Yield to Maturity (2nd July)']
plt.scatter(x,y,color="White")
plt.scatter(x1,y1,color="White")
plt.xlabel('Time to Maturity',fontsize=8)
plt.ylabel('Yield to Maturity', fontsize=8)

z=nm.polyfit(x,y,4)
p=nm.poly1d(z)
plt.plot(x,p(x),'r--')

#---------------------2grahp
#data=df5[['Time to Maturity','Yield to Maturity']]
x1=df2['Time to Maturity (1st July)']
y1=df2['Yield to Maturity (1st July)']

plt.xlabel("Time to Maturity",fontsize=8)
plt.ylabel("Yield to Maturity", fontsize=8)

z1=nm.polyfit(x1,y1,4)
p1=nm.poly1d(z1)
plt.plot(x1,p1(x1),'r--')
plt.show()'''


#data for Government securities
df10=pd.read_excel (r'C:\Users\user\Desktop\Government Securities 1st July.xlsx', sheet_name='1st July') 
df10.reset_index(drop=True)

df11=df10.drop([31,32,33,34,35])
df11
#df12=df11.drop([33,34,35])
# Out:
#     Time to Maturity (2nd July)  Yield to Maturity (2nd July)  \
# 0                            66                        6.6700
# 1                           117                       10.4600
# 2                           120                        7.1931
# 3                           135                        7.4000
# 4                           138                        7.5000
# 5                           141                        7.4000
# 6                           197                        9.3000
# 7                           201                       11.0000
# 8                           208                        8.0500
# 9                           361                        7.9000
# 10                          386                        9.9350
# 11                          423                        8.0800
# 12                          435                        8.1000
# 13                          472                        7.7400
# 14                          575                        7.9529
# 15                          627                        8.1531
# 16                          715                        8.2500
# 17                          759                        9.9366
# 18                          957                        8.1500
# 19                          963                       11.3000
# 20                         1010                        7.8817
# 21                         1020                        8.1500
# 22                         1038                        8.2000
# 23                         1090                        8.2100
# 24                         1097                        9.0000
# 25                         1104                        8.3000
# 26                         1111                        8.2300
# 27                         1121                        8.8443
# 28                         1166                        8.2900
# 29                         1262                        7.6800
# ..                          ...                           ...
# 44                         2267                       10.2634
# 45                         2272                        6.0800
# 46                         2329                        6.1100
# 47                         2794                        6.0434
# 48                         2815                        9.7100
# 49                         2997                       10.2500
# 50                         3122                        6.0800
# 51                         3184                        6.1001
# 52                         3404                        9.6000
# 53                         3406                        8.0362
# 54                         3455                       11.0020
# 6   IN0020160050    2022-12-19              6.5765 2019-06-01
# 7   IN0020180025    2023-04-16              6.6669 2019-06-01
# 8   IN0020130012    2023-05-20              6.7705 2019-06-01
# 9   IN0020030055    2023-06-12              6.6907 2019-06-01
# 10  IN0020180488    2024-01-28              6.7919 2019-06-01
# 11  IN0020090034    2024-06-22              6.8548 2019-06-01
# 12  IN0020140045    2024-07-28              6.8884 2019-06-01
# 13  IN0020150036    2025-05-25              6.9412 2019-06-01
# 14  IN0020120047    2025-09-24              6.9868 2019-06-01
# 15  IN0020150093    2026-01-11              7.0047 2019-06-01
# 16  IN0020190016    2026-04-08              6.9344 2019-06-01
# 17  IN0020060078    2027-02-15              7.0500 2019-06-01
# 18  IN0020170026    2027-05-15              7.0328 2019-06-01
# 19  IN0020070036    2027-08-02              7.0758 2019-06-01
# 20  IN0020170174    2028-01-08              7.0318 2019-06-01
# 21  IN0020020247    2028-03-25              7.0730 2019-06-01
# 22  IN0020180454    2029-01-14              6.9055 2019-06-01
# 23  IN0020150069    2029-03-20              7.0523 2019-06-01
# 24  IN0020150028    2030-03-19              7.0505 2019-06-01
# 25  IN0020160019    2030-05-09              7.0455 2019-06-01
# 26  IN0020130053    2030-09-30              7.0697 2019-06-01
# 27  IN0020110055    2030-12-05              7.0834 2019-06-01
# 28  IN0020170042    2031-09-17              7.0426 2019-06-01
# 29  IN0020070044    2032-08-02              7.0641 2019-06-01
# 30  IN0020020106    2032-08-28              7.0751 2019-06-01
#
#     Time to Maturity
# 0                215
# 1                313
# 2                600
# 3                723
# 4                990
# 5               1158
# 6               1297
# 7               1415
# 8               1449
# 9               1472
# 10              1702
# 11              1848
# 12              1884
# 13              2185
# 14              2307
# 15              2416
# 16              2503
# 17              2816
# 18              2905
# 19              2984
# 20              3143
# 21              3220
# 22              3515
# 23              3580
# 24              3944
# 25              3995
# 26              4139
# 27              4205
# 28              4491
# 29              4811
# 30              4837

# %%
#matplotlib CBs vs Gsec
plt.figure(figsize=(18,8))
plt.title('Coporate Bonds vs Government securities Yield curve (1st July)')
x=df4['Time to Maturity (1st July)']
y=df4['Yield to Maturity (1st July)']

plt.xlabel("Time to Maturity",fontsize=8)
plt.ylabel('Yield to Maturity', fontsize=8)

z=np.polyfit(x,y,4)
p=np.poly1d(z)
plt.plot(x,p(x),'r--', label ='Corporate Bond',c='blue' )
#plt.show()


x1=df11['Time to Maturity']
y1=df11['Weighted Avg Yield']

plt.xlabel("Time to Maturity",fontsize=8)
plt.ylabel('Yield to Maturity', fontsize=8)

z1=np.polyfit(x1,y1,4)
p1=np.poly1d(z1)
plt.plot(x1,p1(x1),'r--', label= "Government Securities", c= 'red')
plt.legend()
plt.show()

#seaborn plot
plt.figure(figsize=(8,10))

sns.regplot(x="Time to Maturity (1st July)",y="Yield to Maturity (1st July)",data=d3,order=4)
sns.regplot(x='Time to Maturity', y='Weighted Avg Yield', data=df10,order=4)
